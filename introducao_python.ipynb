# %% [markdown]
# <a href="https://colab.research.google.com/github/kaykegasparini/Atividade-React/blob/main/introducao_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Introdução ao Colab***

# %%
print("Hello word.")
# Out:
# Hello word.

# %%
2+2
# Out:
# 4

# %%
2+4
# Out:
# 6

# %%
nome = 'Kayke'
print("Oi,",nome)
# Out:
# Oi, Kayke

# %%
nome = 12
nome
# Out:
# 12

# %%
a = 4
b = 6

if a < b:
  print('a < b')
# Out:
# a < b

# %%
if a < b:
  print('a < b')
else:
  print('a >= b')
# Out:
# a < b

# %%
a = 6

if a < b:
  print('a < b')
elif a > b:
  print('a > b')
else:
  print('a == b')
# Out:
# a == b

# %%
for i in range(10):
  print(i, 'Olá Mundo')
# Out:
# 0 Olá Mundo
# 1 Olá Mundo
# 2 Olá Mundo
# 3 Olá Mundo
# 4 Olá Mundo
# 5 Olá Mundo
# 6 Olá Mundo
# 7 Olá Mundo
# 8 Olá Mundo
# 9 Olá Mundo

# %%
for i in range(2, 11, 2):
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(5, 0, -1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
lista = [1, 2, 3]
lista
# Out:
# [1, 2, 3, 'kayke']

# %%
lista = [1, 2, 3, "texto", ['a', "b", "c"]]
lista
# Out:
# [1, 2, 3, 'texto', ['a', 'b', 'c']]

# %%
lista[-1][2]
# Out:
# 'c'

# %%
lista[2:4]
# Out:
# [3, 'texto']

# %%
for i in lista:
  print(i)
# Out:
# 1
# 2
# 3
# texto
# ['a', 'b', 'c']

# %%
dicionario = {"chave":"valor"}
dicionario
# Out:
# {'chave': 'valor'}

# %%
dicionario = {"chave":"valor", 2:"valor2", "chave3":[1, 2, 3, "Kayke", [2, 4, 6]], "kayke":"joyce"}
dicionario
# Out:
# {'chave': 'valor',
#  2: 'valor2',
#  'chave3': [1, 2, 3, 'Kayke', [2, 4, 6]],
#  'kayke': 'joyce'}

# %%
dicionario["kayke"]
# Out:
# 'joyce'

# %%
lista
# Out:
# [1, 2, 3, 'texto', ['a', 'b', 'c']]

# %%
lista[3] = [5, 6, 7]
lista
# Out:
# [1, 2, 3, [5, 6, 7], ['a', 'b', 'c']]

# %%
dicionario
# Out:
# {'chave': 'valor',
#  2: 'valor2',
#  'chave3': [1, 2, 3, 'Kayke', [2, 4, 6]],
#  'kayke': 'joyce'}

# %%
dicionario['chave'] = {1:'valor1', 2:'valor2'}
dicionario
# Out:
# {'chave': {1: 'valor1', 2: 'valor2'},
#  2: 'valor2',
#  'chave3': [1, 2, 3, 'Kayke', [2, 4, 6]],
#  'kayke': 'joyce'}

# %% [markdown]
# # **Remoção de dados**

# %%
lista
# Out:
# [1, 2, 3, [5, 6, 7], ['a', 'b', 'c']]

# %%
lista.pop(3)
lista
# Out:
# [1, 2, 3, ['a', 'b', 'c']]

# %%
dicionario
# Out:
# {'chave': {1: 'valor1', 2: 'valor2'},
#  2: 'valor2',
#  'chave3': [1, 2, 3, 'Kayke', [2, 4, 6]],
#  'kayke': 'joyce'}

# %%
dicionario.pop("chave3")
dicionario
# Out:
# {'chave': {1: 'valor1', 2: 'valor2'}, 2: 'valor2', 'kayke': 'joyce'}

# %%
dicionario.pop("kayke")
dicionario
# Out:
# {'chave': {1: 'valor1', 2: 'valor2'}, 2: 'valor2'}
